# %% [markdown]
# # Week 4 Practice (Office Hours)

# %% [markdown]
# ## Example 1
# This example covers:
# - % operator
# - Functions
# - Parameters vs arguments
# - Booleans

# %%
def odd_or_even(n):
    result = n % 2 == 0
    return result

# %% [markdown]
# <details>
#   <summary><b>Look at n in the first line. Is it a parameter or an argument?</b></summary>
#   Parameter
# </details>
# <details>
#   <summary><b>Why?</b></summary>
#       A parameter is what is written within the parentheses of a function definition.
#   An argument is the value that is actually passed into the function.
# </details>

# %% [markdown]
# Now, call the function; make odd_or_even return False

# %%
# Write your code here

# %% [markdown]
# Now, we'll make the function return True

# %%
outcome = odd_or_even(2)
print(outcome)
# Out:
# True

# %% [markdown]
# <details>
#   <summary><b>Look at the number 2 in the first line. Is it a parameter or an argument?</b></summary>
#   Argument
# </details>
# <details>
#   <summary><b>Why?</b></summary>
#   A parameter is what is written within the parentheses of a function definition.
#   An argument is the value that is actually passed into the function.
# </details>

# %% [markdown]
# <details>
#   <summary><b>What is the output of print(outcome)?</b></summary>
#   True
# </details>
# <br>
# <details>
#   <summary><b>Now, what is the type of outcome?</b></summary>
#   The type of outcome is bool which means Boolean.
# </details>

# %%
type(outcome)
# Out:
# bool

# %% [markdown]
# ## Example 2
# This example covers:
# - Conditionals (includeds chained vs nested)
# - Booleans

# %% [markdown]
# <details>
#   <summary><b>Write a one-line conditional Boolean statement to determine if a customer can get a discount.</b></summary>
#   <pre>customer <= 13 or customer >= 65</pre>
# </details>

# %%
# Write your code here

# %% [markdown]
# <details>
#   <summary><b>Now, print "Eligible" if the customer is eligible for a discount and "Ineligible" if not.</b></summary>
#   <pre>
#     if customer <= 13 or customer >= 65:
#       print("Eligible")
#     else:
#       print("Not elgibile")</pre>
# </details>

# %%
# Write your code here

# %% [markdown]
# <details>
#   <summary><b>Next, write a chained conditional that prints "Child discount" if the customer is 13 or younger and "Senior discount" if the customer is 65 or older. Print "No discount" if none of these apply.</b></summary>
#   <pre>
#   if customer <= 13:
#     print("Child discount")
#   elif customer >= 65:
#     print("Senior discount")
#   else:
#     print("No discount")
#   </pre>
# </details>

# %%
# Write your code here

# %% [markdown]
# <details>
#   <summary><b>Now write a Boolean expression for the following scenario: customers get a discount if they are age 13 and less, or if they are age 65+ as well as a member.</b></summary>
#   <pre>
#   customer <= 13 or (customer >= 65 and is_member)
#   </pre>
# </details>

# %%
# Write your code here

# %% [markdown]
# <details>
#   <summary><b>Now write a nested conditional statement that first checks if the customer is a member or not. If they are a member, the code prints "Child discount" if they are 13- and "Senior discount" if they are 65+. Print "You are not eligible for a discount" for those who do not fit into those categories. "Non-members cannot get discounts" is printed if the customer is not a member.</b></summary>
#   <pre>
#     if is_member:
#         if customer <= 13:
#             print("Child discount")
#         elif customer >= 65:
#             print("Senior discount")
#         else:
#             print("You are not eligible for a discount.")
#     else:
#         print("Non-members cannot get discounts.")
#
#   </pre>
# </details>

# %%
# Write your code here
